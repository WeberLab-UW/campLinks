# %% [markdown]
# ## AI Text Detection ##
#
# We run Pangram on all cleaned sampled texted across all sampled candidates. The final dataframe returns the given CSV with the additional columns of label_final, ai_assistance_final, confidence_final, fraction_ai, fraction_ai_assisted, fraction_human, and num_ai_segments; all of these scores are obtained with the Pangram API using research credits

# %%
import pandas as pd
from pangram import Pangram
import numpy as np
import random
import re
from collections import Counter #for extracting labels and confidence majorities with pangram
import os
from dotenv import load_dotenv

# %%
governor_data = pd.read_csv("../governor_content.csv")

# %%
ag_data = pd.read_csv("../ag_content.csv")

# %%
mayor_data = pd.read_csv("../mayor_content.csv")

# %%
us_senate_data = pd.read_csv("../us_senate_content.csv")

# %%
us_house_data = pd.read_csv("../us_house_content.csv")

# %%
state_house_data = pd.read_csv("../state_house_content.csv")

# %%
state_senate_data = pd.read_csv("../state_senate_content.csv")

# %%
load_dotenv()
pangram_client = Pangram(api_key=os.getenv("PANGRAM_API_KEY"))

# %% [markdown]
# ### Data Cleaning ###
# This notebook uses data queried from camplinks.db from the Content table to get the sampled text for all candidates in our database.This is loaded in as "data". We then clean the dataframe by dropping rows where the unprocessed_text and sampled_text are both NA or where sampled_text = ERROR: could not fetch page.
#
# The dataframe also contains features of candidates that have been combined from the camplinks.db, allowing for easier future analysis using only one CSV

# %%
#add columns to datasets to fill in with pangram results

def add_columns(df):
    columns_to_add = [
        'AI_label',
        'assistance_score',
        'confidence',
        'fraction_ai',
        'fraction_ai_assisted',
        'fraction_human',
        'num_ai_segments'
    ]
    
    for col in columns_to_add:
        df[col] = float('nan')

    return df


def clean_data(df):
    df_filtered = df[~(df['unprocessed_text'].isna() & df['sampled_text'].isna())]
    df_cleaned = df_filtered[df_filtered['sampled_text'] != 'ERROR: could not fetch page']
    return df_cleaned

# %%
#some exploratory functions:

def avg_word_count(df):
    return df['sampled_text'].str.split().str.len().mean()

def cand_amount(df):
    return df['candidate_name'].nunique()

# %% [markdown]
# Clean and add columns:

# %%
gov_cleaned = clean_data(governor_data)
gov_added = add_columns(gov_cleaned)

# %%
ag_cleaned = clean_data(ag_data)
ag_added = add_columns(ag_cleaned)

# %%
mayor_cleaned = clean_data(mayor_data)
mayor_added = add_columns(mayor_cleaned)

# %%
us_senate_cleaned = clean_data(us_senate_data)
us_senate_added = add_columns(us_senate_cleaned)

# %%
us_house_cleaned = clean_data(us_house_data)
us_house_added = add_columns(us_house_cleaned)

# %%
state_senate_cleaned = clean_data(state_senate_data)
state_senate_added = add_columns(state_senate_cleaned)

# %%
state_house_cleaned = clean_data(state_house_data)
state_house_added = add_columns(state_house_cleaned)

# %% [markdown]
# Get some exploratory information

# %%
#exploratory info
print('governor candidates:', cand_amount(gov_added), '- average word count and text samples: ', avg_word_count(gov_added) , ', ' , len(gov_added))
print('attorney general candidates:', cand_amount(ag_added), '- average word count and text samples: ', avg_word_count(ag_added), ', ', len(ag_added))
print('mayoral candidates:', cand_amount(mayor_added), '- average word count and text samples: ', avg_word_count(mayor_added), ', ', len(mayor_added))
print('US senate candidates:', cand_amount(us_senate_added), '- average word count and text samples: ', avg_word_count(us_senate_added), ', ', len(us_senate_added))
print('US house candidates:', cand_amount(us_house_added), '- average word count and text samples: ', avg_word_count(us_house_added), ', ', len(us_house_added))
print('State senate candidates:', cand_amount(state_senate_added), '- average word count and text samples:  ', avg_word_count(state_senate_added), ', ', len(state_senate_added))
print('State house candidates:', cand_amount(state_house_added), ' - average word count and text samples: ', avg_word_count(state_house_added), ', ', len(state_house_added))
# Out:
# governor candidates: 29 - average word count and text samples:  242.83582089552237 ,  67
# attorney general candidates: 26 - average word count and text samples:  206.02325581395348 ,  43
# mayoral candidates: 155 - average word count and text samples:  281.3973941368078 ,  307
# US senate candidates: 58 - average word count and text samples:  237.9624060150376 ,  133
# US house candidates: 809 - average word count and text samples:  292.2930513595166 ,  1986
# State senate candidates: 1469 - average word count and text samples:   242.05026769779892 ,  3362
# State house candidates: 6615  - average word count and text samples:  238.12985064892715 ,  15333

# %%
#combine all tables together to view across all races (this is just exploratory, detection will be ran on individual dataframes(
combined = pd.concat([gov_added, ag_added, mayor_added, us_senate_added, us_house_added, state_senate_added, state_house_added], ignore_index=True)
combined.head()
# Out:
#    content_id  candidate_id  candidate_name  \
# 0           1          6179    Andy Beshear
# 1           2          6180  Daniel Cameron
# 2           3          6180  Daniel Cameron
# 3           4          6180  Daniel Cameron
# 4           5          6180  Daniel Cameron
#
#                                           page_url page_type      link_type  \
# 0                         https://andybeshear.com/      home  campaign_site
# 1                  https://cameronforkentucky.com/      home  campaign_site
# 2    https://cameronforkentucky.com/policies/terms    policy  campaign_site
# 3  https://cameronforkentucky.com/policies/privacy    policy  campaign_site
# 4           https://cameronforkentucky.com/issues/    policy  campaign_site
#
#                                     unprocessed_text  \
# 0  Andy Beshear Menu Meet Andy Meet Jacqueline An...
# 1  Menu News Facebook Twitter Instagram Donate › ...
# 2  Menu News Facebook Twitter Instagram Donate › ...
# 3  Menu News Facebook Twitter Instagram Donate › ...
# 4  Menu News Facebook Twitter Instagram Donate › ...
#
#                                         cleaned_text  \
# 0  Andy Beshear Menu Meet Andy Meet Jacqueline An...
# 1  Menu News Facebook Twitter Instagram Donate  S...
# 2  Menu News Facebook Twitter Instagram Donate  S...
# 3  Menu News Facebook Twitter Instagram Donate  S...
# 4  Menu News Facebook Twitter Instagram Donate  S...
#
#                                         sampled_text race_type  year  \
# 0  Andy Beshear Menu Meet Andy Meet Jacqueline An...  Governor  2023
# 1  I'm In! QUICK DONATE $25 $50 $100 ENTER AMOUNT...  Governor  2023
# 2  Data Privacy We will not share or sell your pe...  Governor  2023
# 3  This Privacy Policy explains how we collect, u...  Governor  2023
# 4  He will always oppose the radical green agenda...  Governor  2023
#
#    AI_label  assistance_score  confidence  fraction_ai  fraction_ai_assisted  \
# 0       NaN               NaN         NaN          NaN                   NaN
# 1       NaN               NaN         NaN          NaN                   NaN
# 2       NaN               NaN         NaN          NaN                   NaN
# 3       NaN               NaN         NaN          NaN                   NaN
# 4       NaN               NaN         NaN          NaN                   NaN
#
#    fraction_human  num_ai_segments
# 0             NaN              NaN
# 1             NaN              NaN
# 2             NaN              NaN
# 3             NaN              NaN
# 4             NaN              NaN

# %%
print('Total candidates:', cand_amount(combined), ' - average word count and text samples: ', avg_word_count(combined), ', ', len(combined))
# Out:
# Total candidates: 9126  - average word count and text samples:  244.39164429372144 ,  21231

# %%
combined['page_type'].value_counts() / len(combined)
# Out:
# page_type
# home      0.442560
# about     0.293533
# policy    0.263907
# Name: count, dtype: float64

# %% [markdown]
# ### Running AI Text Detection ###

# %%
#add in empty columns so that we don't accidently lose any pangram data
#instead, automatically append an entire row once its done; additionally run in batches

# %%
#code source from pangram: https://pangram.readthedocs.io/en/latest/api/pangram.html

def check_AI(text):
    valid_API_call = False
    try:
        result = pangram_client.predict(text)
        valid_API_call = True
    except:
        fraction_ai = float('nan')
        fraction_ai_assisted = float('nan')
        fraction_human = float('nan')
        num_ai_segments = float('nan')
        AI_label = float('nan')
        confidence_final = float('nan')
        assistance_score = float('nan')

    if valid_API_call:
        AI_label = result['prediction_short']
        confidence_all = []
        ai_assistance_all = []
        fraction_ai = result['fraction_ai']
        fraction_ai_assisted = result['fraction_ai_assisted']
        fraction_human = result['fraction_human']
        num_ai_segments = result['num_ai_segments']

        #for some reason, confidence is only per-window. So to get it we need to average out window confidence. Though, there tends
        #to be only 1 or 2 windows so not big deal
        for window in result['windows']:
            confidence = window['confidence']
            confidence_all.append(confidence)

            ai_assistance_score = window['ai_assistance_score'] #same with these
            ai_assistance_all.append(ai_assistance_score)
            
        confidence = Counter(confidence_all).most_common(1)[0][0]
        assistance_score =  np.mean(ai_assistance_all)

    else:
        return ['unable to run', 'unable to run', 'unable to run', 'unable to run', 'unable to run', 'unable to run', 'unable to run']

    #print(AI_label, confidence, fraction_ai, fraction_ai_assisted, fraction_human, num_ai_segments)
    return [AI_label, assistance_score, confidence, fraction_ai, fraction_ai_assisted, fraction_human, num_ai_segments]

# %%
def check_entire_race(race_df):
    for idx, row in race_df.iterrows():
        try:
            result = check_AI(row['sampled_text'])
            print(row['candidate_name'], result)
            race_df.loc[idx, ['AI_label', 'assistance_score', 'confidence', 'fraction_ai', 'fraction_ai_assisted', 'fraction_human', 'num_ai_segments']] = result
        except Exception as e:
            print(f"Row {idx} failed: {e}")
            # row stays None/NaN, loop continues

# %%
len(us_senate_added)
# Out:
# 133

# %%
check_entire_race(us_senate_added)
# Out:
# Kari Lake ['Human', 0.058674976229667664, 'Medium', 0.0, 0.0, 1.0, 0]
# /var/folders/17/gz6b52jj5cvfsq17xw_vghsh0000gn/T/ipykernel_64413/2149402114.py:6: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Human' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   race_df.loc[idx, ['AI_label', 'assistance_score', 'confidence', 'fraction_ai', 'fraction_ai_assisted', 'fraction_human', 'num_ai_segments']] = result
# /var/folders/17/gz6b52jj5cvfsq17xw_vghsh0000gn/T/ipykernel_64413/2149402114.py:6: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Medium' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   race_df.loc[idx, ['AI_label', 'assistance_score', 'confidence', 'fraction_ai', 'fraction_ai_assisted', 'fraction_human', 'num_ai_segments']] = result
# Kari Lake ['unable to run', 'unable to run', 'unable to run', 'unable to run', 'unable to run', 'unable to run', 'unable to run']
# /var/folders/17/gz6b52jj5cvfsq17xw_vghsh0000gn/T/ipykernel_64413/2149402114.py:6: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'unable to run' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   race_df.loc[idx, ['AI_label', 'assistance_score', 'confidence', 'fraction_ai', 'fraction_ai_assisted', 'fraction_human', 'num_ai_segments']] = result
# /var/folders/17/gz6b52jj5cvfsq17xw_vghsh0000gn/T/ipykernel_64413/2149402114.py:6: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'unable to run' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   race_df.loc[idx, ['AI_label', 'assistance_score', 'confidence', 'fraction_ai', 'fraction_ai_assisted', 'fraction_human', 'num_ai_segments']] = result
# /var/folders/17/gz6b52jj5cvfsq17xw_vghsh0000gn/T/ipykernel_64413/2149402114.py:6: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'unable to run' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   race_df.loc[idx, ['AI_label', 'assistance_score', 'confidence', 'fraction_ai', 'fraction_ai_assisted', 'fraction_human', 'num_ai_segments']] = result
# /var/folders/17/gz6b52jj5cvfsq17xw_vghsh0000gn/T/ipykernel_64413/2149402114.py:6: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'unable to run' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   race_df.loc[idx, ['AI_label', 'assistance_score', 'confidence', 'fraction_ai', 'fraction_ai_assisted', 'fraction_human', 'num_ai_segments']] = result
# /var/folders/17/gz6b52jj5cvfsq17xw_vghsh0000gn/T/ipykernel_64413/2149402114.py:6: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'unable to run' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   race_df.loc[idx, ['AI_label', 'assistance_score', 'confidence', 'fraction_ai', 'fraction_ai_assisted', 'fraction_human', 'num_ai_segments']] = result
# Kari Lake ['Human', 0.014941799454391003, 'High', 0.0, 0.0, 1.0, 0]
# Ruben Gallego ['Human', 0.005045536223665944, 'High', 0.0, 0.0, 1.0, 0]
# Ruben Gallego ['Human', 0.010151629336178303, 'High', 0.0, 0.0, 1.0, 0]
# Ruben Gallego ['Human', 0.006716141011565924, 'High', 0.0, 0.0, 1.0, 0]
# Ruben Gallego ['unable to run', 'unable to run', 'unable to run', 'unable to run', 'unable to run', 'unable to run', 'unable to run']
# Ruben Gallego ['Human', 0.004454157315194607, 'High', 0.0, 0.0, 1.0, 0]
# Ruben Gallego ['Human', 0.008216402493417263, 'High', 0.0, 0.0, 1.0, 0]
# Ruben Gallego ['Human', 0.005655944813042879, 'High', 0.0, 0.0, 1.0, 0]
# Ruben Gallego ['Human', 0.00491423299536109, 'High', 0.0, 0.0, 1.0, 0]
# Adam B. Schiff ['Human', 0.007768214214593172, 'High', 0.0, 0.0, 1.0, 0]
# Adam B. Schiff ['unable to run', 'unable to run', 'unable to run', 'unable to run', 'unable to run', 'unable to run', 'unable to run']
# Adam B. Schiff ['Human', 0.0053487834923614105, 'High', 0.0, 0.0, 1.0, 0]
# Steve Garvey ['Human', 0.0065215532667934895, 'High', 0.0, 0.0, 1.0, 0]
# Christopher S. Murphy ['Human', 0.004320540931075811, 'High', 0.0, 0.0, 1.0, 0]
# Christopher S. Murphy ['Human', 0.0051271050348683875, 'High', 0.0, 0.0, 1.0, 0]
# Matthew M. Corey ['Human', 0.021321143954992294, 'High', 0.0, 0.0, 1.0, 0]
# Lisa Blunt Rochester ['Human', 0.004278694728522429, 'High', 0.0, 0.0, 1.0, 0]
# Lisa Blunt Rochester ['Human', 0.0071168504655361176, 'High', 0.0, 0.0, 1.0, 0]
# Lisa Blunt Rochester ['Human', 0.006535376887768507, 'High', 0.0, 0.0, 1.0, 0]
# Lisa Blunt Rochester ['Human', 0.01815187931060791, 'High', 0.0, 0.0, 1.0, 0]
# Lisa Blunt Rochester ['Human', 0.006390857044607401, 'High', 0.0, 0.0, 1.0, 0]
# Debbie Mucarsel-Powell ['Human', 0.005605597204218308, 'High', 0.0, 0.0, 1.0, 0]
# Rick Scott ['unable to run', 'unable to run', 'unable to run', 'unable to run', 'unable to run', 'unable to run', 'unable to run']
# Bob Mcdermott ['Human', 0.2648199200630188, 'Low', 0.0, 0.0, 1.0, 0]
# Mazie K. Hirono ['Human', 0.005879802629351616, 'High', 0.0, 0.0, 1.0, 0]
# Mazie K. Hirono ['Human', 0.005200216080993414, 'High', 0.0, 0.0, 1.0, 0]
# Mazie K. Hirono ['Human', 0.004769904538989067, 'High', 0.0, 0.0, 1.0, 0]
# Mazie K. Hirono ['Human', 0.005585611332207918, 'High', 0.0, 0.0, 1.0, 0]
# Jim Banks ['Human', 0.003982893191277981, 'High', 0.0, 0.0, 1.0, 0]
# Jim Banks ['Human', 0.004365506608400753, 'High', 0.0, 0.0, 1.0, 0]
# Valerie Mccray ['Human', 0.004573614425227092, 'High', 0.0, 0.0, 1.0, 0]
# Valerie Mccray ['Human', 0.004239722471562475, 'High', 0.0, 0.0, 1.0, 0]
# Valerie Mccray ['Human', 0.06334768735211004, 'Medium', 0.0, 0.0, 1.0, 0]
# Elizabeth Ann Warren ['Human', 0.0071240877732634544, 'High', 0.0, 0.0, 1.0, 0]
# Elizabeth Ann Warren ['Human', 0.005157956387847662, 'High', 0.0, 0.0, 1.0, 0]
# John Deaton ['Human', 0.004946868442108526, 'High', 0.0, 0.0, 1.0, 0]
# John Deaton ['AI', 0.5924497842788696, 'Low', 1.0, 0.0, 0.0, 1]
# Angela Alsobrooks ['Human', 0.007992289029061794, 'High', 0.0, 0.0, 1.0, 0]
# Angela Alsobrooks ['Human', 0.012381128035485744, 'High', 0.0, 0.0, 1.0, 0]
# Larry Hogan ['unable to run', 'unable to run', 'unable to run', 'unable to run', 'unable to run', 'unable to run', 'unable to run']
# Angus S. King Jr. ['Human', 0.00846250168979168, 'High', 0.0, 0.0, 1.0, 0]
# Angus S. King Jr. ['unable to run', 'unable to run', 'unable to run', 'unable to run', 'unable to run', 'unable to run', 'unable to run']
# Demi Kouzounas ['Human', 0.0048009371384978294, 'High', 0.0, 0.0, 1.0, 0]
# Demi Kouzounas ['Human', 0.021341567859053612, 'High', 0.0, 0.0, 1.0, 0]
# Elissa Slotkin ['Human', 0.00480796629562974, 'High', 0.0, 0.0, 1.0, 0]
# Elissa Slotkin ['Human', 0.005108480341732502, 'High', 0.0, 0.0, 1.0, 0]
# Elissa Slotkin ['unable to run', 'unable to run', 'unable to run', 'unable to run', 'unable to run', 'unable to run', 'unable to run']
# Elissa Slotkin ['unable to run', 'unable to run', 'unable to run', 'unable to run', 'unable to run', 'unable to run', 'unable to run']
# Elissa Slotkin ['Human', 0.004747288767248392, 'High', 0.0, 0.0, 1.0, 0]
# Elissa Slotkin ['Human', 0.005304357968270779, 'High', 0.0, 0.0, 1.0, 0]
# Mike Rogers ['Human', 0.05164572224020958, 'Medium', 0.0, 0.0, 1.0, 0]
# Amy Klobuchar ['Human', 0.0058662849478423595, 'High', 0.0, 0.0, 1.0, 0]
# Royce White ['Human', 0.10075321048498154, 'Medium', 0.0, 0.0, 1.0, 0]
# Josh Hawley ['Human', 0.006437868345528841, 'High', 0.0, 0.0, 1.0, 0]
# Lucas Kunce ['Human', 0.004685312509536743, 'High', 0.0, 0.0, 1.0, 0]
# Roger F. Wicker ['Human', 0.008066403679549694, 'High', 0.0, 0.0, 1.0, 0]
# Ty Pinkins ['Human', 0.005822607781738043, 'High', 0.0, 0.0, 1.0, 0]
# Ty Pinkins ['Human', 0.005038270261138678, 'High', 0.0, 0.0, 1.0, 0]
# Jon Tester ['Human', 0.007878286764025688, 'High', 0.0, 0.0, 1.0, 0]
# Jon Tester ['Human', 0.004958138699294067, 'High', 0.0, 0.0, 1.0, 0]
# Jon Tester ['unable to run', 'unable to run', 'unable to run', 'unable to run', 'unable to run', 'unable to run', 'unable to run']
# Tim Sheehy ['unable to run', 'unable to run', 'unable to run', 'unable to run', 'unable to run', 'unable to run', 'unable to run']
# Kevin Cramer ['unable to run', 'unable to run', 'unable to run', 'unable to run', 'unable to run', 'unable to run', 'unable to run']
# Kevin Cramer ['Human', 0.004020784981548786, 'High', 0.0, 0.0, 1.0, 0]
# Kevin Cramer ['Mixed', 0.5632595240706557, 'Low', 0.0, 0.11753590325018896, 0.8824640967498111, 0]
# Dan Osborn ['Human', 0.008001038804650307, 'High', 0.0, 0.0, 1.0, 0]
# Dan Osborn ['Human', 0.004569520399125183, 'High', 0.0, 0.0, 1.0, 0]
# Deb Fischer ['Human', 0.011212653402859965, 'High', 0.0, 0.0, 1.0, 0]
# Andy Kim ['Human', 0.010192829184234142, 'High', 0.0, 0.0, 1.0, 0]
# Andy Kim ['Human', 0.009194204583764076, 'High', 0.0, 0.0, 1.0, 0]
# Andy Kim ['Human', 0.004826822783797979, 'High', 0.0, 0.0, 1.0, 0]
# Martin Heinrich ['Human', 0.08699240535497665, 'Medium', 0.0, 0.0, 1.0, 0]
# Martin Heinrich ['AI', 0.663730479138238, 'Low', 1.0, 0.0, 0.0, 1]
# Martin Heinrich ['unable to run', 'unable to run', 'unable to run', 'unable to run', 'unable to run', 'unable to run', 'unable to run']
# Jacky S. Rosen ['Human', 0.01021988969296217, 'High', 0.0, 0.0, 1.0, 0]
# Jacky S. Rosen ['Human', 0.0046255080960690975, 'High', 0.0, 0.0, 1.0, 0]
# Sam Brown ['Human', 0.030123770925337856, 'High', 0.0, 0.0, 1.0, 0]
# Kirsten E. Gillibrand ['unable to run', 'unable to run', 'unable to run', 'unable to run', 'unable to run', 'unable to run', 'unable to run']
# Kirsten E. Gillibrand ['Human', 0.0047079455107450485, 'High', 0.0, 0.0, 1.0, 0]
# Bernie Moreno ['Human', 0.005371643230319023, 'High', 0.0, 0.0, 1.0, 0]
# Bernie Moreno ['Human', 0.06812810152769089, 'Medium', 0.0, 0.0, 1.0, 0]
# Sherrod Brown ['Human', 0.0047240303829312325, 'High', 0.0, 0.0, 1.0, 0]
# Dave Mccormick ['Human', 0.004919086582958698, 'High', 0.0, 0.0, 1.0, 0]
# Dave Mccormick ['Human', 0.005843314329536367, 'High', 0.0, 0.0, 1.0, 0]
# Robert P Casey Jr ['Human', 0.004729846026748419, 'High', 0.0, 0.0, 1.0, 0]
# Robert P Casey Jr ['Human', 0.004662956576794386, 'High', 0.0, 0.0, 1.0, 0]
# Sheldon Whitehouse ['Human', 0.005985196214169264, 'High', 0.0, 0.0, 1.0, 0]
# Sheldon Whitehouse ['Human', 0.006343228742480278, 'High', 0.0, 0.0, 1.0, 0]
# Marsha Blackburn ['Human', 0.025388190503387403, 'High', 0.0, 0.0, 1.0, 0]
# Marsha Blackburn ['Human', 0.03484184667468071, 'High', 0.0, 0.0, 1.0, 0]
# Marsha Blackburn ['unable to run', 'unable to run', 'unable to run', 'unable to run', 'unable to run', 'unable to run', 'unable to run']
# Marsha Blackburn ['Human', 0.004899672232568264, 'High', 0.0, 0.0, 1.0, 0]
# Marsha Blackburn ['Human', 0.005929759703576565, 'High', 0.0, 0.0, 1.0, 0]
# Marsha Blackburn ['unable to run', 'unable to run', 'unable to run', 'unable to run', 'unable to run', 'unable to run', 'unable to run']
# Colin Allred ['unable to run', 'unable to run', 'unable to run', 'unable to run', 'unable to run', 'unable to run', 'unable to run']
# Ted Cruz ['Human', 0.005136507097631693, 'High', 0.0, 0.0, 1.0, 0]
# Caroline Gleich ['Human', 0.009829466231167316, 'High', 0.0, 0.0, 1.0, 0]
# John Curtis ['Human', 0.08547747880220413, 'Medium', 0.0, 0.0, 1.0, 0]
# John Curtis ['Human', 0.0055795954540371895, 'High', 0.0, 0.0, 1.0, 0]
# Hung Cao ['Human', 0.006086681969463825, 'High', 0.0, 0.0, 1.0, 0]
# Timothy M. Kaine ['Human', 0.007659426890313625, 'High', 0.0, 0.0, 1.0, 0]
# Timothy M. Kaine ['Human', 0.0058019887655973434, 'High', 0.0, 0.0, 1.0, 0]
# Timothy M. Kaine ['Human', 0.005515699274837971, 'High', 0.0, 0.0, 1.0, 0]
# Timothy M. Kaine ['Human', 0.0045991456136107445, 'High', 0.0, 0.0, 1.0, 0]
# Timothy M. Kaine ['Human', 0.004545229021459818, 'High', 0.0, 0.0, 1.0, 0]
# Timothy M. Kaine ['Human', 0.004842336755245924, 'High', 0.0, 0.0, 1.0, 0]
# Timothy M. Kaine ['Human', 0.004679535515606403, 'High', 0.0, 0.0, 1.0, 0]
# Timothy M. Kaine ['unable to run', 'unable to run', 'unable to run', 'unable to run', 'unable to run', 'unable to run', 'unable to run']
# Timothy M. Kaine ['unable to run', 'unable to run', 'unable to run', 'unable to run', 'unable to run', 'unable to run', 'unable to run']
# Timothy M. Kaine ['Human', 0.006804253906011581, 'High', 0.0, 0.0, 1.0, 0]
# Timothy M. Kaine ['Human', 0.006758694536983967, 'High', 0.0, 0.0, 1.0, 0]
# Timothy M. Kaine ['Human', 0.004854658152908087, 'High', 0.0, 0.0, 1.0, 0]
# Timothy M. Kaine ['Human', 0.0046029346995055676, 'High', 0.0, 0.0, 1.0, 0]
# Timothy M. Kaine ['Human', 0.006763790734112263, 'High', 0.0, 0.0, 1.0, 0]
# Timothy M. Kaine ['Human', 0.00460796533152461, 'High', 0.0, 0.0, 1.0, 0]
# Bernie Sanders ['Human', 0.01731393299996853, 'High', 0.0, 0.0, 1.0, 0]
# Bernie Sanders ['Human', 0.09087523818016052, 'Medium', 0.0, 0.0, 1.0, 0]
# Gerald Malloy ['Human', 0.008890820667147636, 'High', 0.0, 0.0, 1.0, 0]
# Gerald Malloy ['Human', 0.008487442508339882, 'High', 0.0, 0.0, 1.0, 0]
# Dr Raul Garcia ['Human', 0.011922508555774888, 'High', 0.0, 0.0, 1.0, 0]
# Maria Cantwell ['Human', 0.004642529413104057, 'High', 0.0, 0.0, 1.0, 0]
# Maria Cantwell ['Human', 0.005232797112290023, 'High', 0.0, 0.0, 1.0, 0]
# Maria Cantwell ['Human', 0.13206210732460022, 'Medium', 0.0, 0.0, 1.0, 0]
# Eric Hovde ['Human', 0.0043180715292692184, 'High', 0.0, 0.0, 1.0, 0]
# Tammy Baldwin ['Human', 0.005102196242660284, 'High', 0.0, 0.0, 1.0, 0]
# Tammy Baldwin ['Human', 0.015259616076946259, 'High', 0.0, 0.0, 1.0, 0]
# Tammy Baldwin ['Human', 0.004686219617724419, 'High', 0.0, 0.0, 1.0, 0]
# Glenn Elliott ['Human', 0.10337324101816525, 'Medium', 0.0, 0.0, 1.0, 0]
# Jim Justice ['Human', 0.004607409238815308, 'High', 0.0, 0.0, 1.0, 0]
# Jim Justice ['Human', 0.004374942742288113, 'High', 0.0, 0.0, 1.0, 0]
# John Barrasso ['Human', 0.005337647162377834, 'High', 0.0, 0.0, 1.0, 0]

# %%
#export done races:

#governor: DONE
#gov_added.to_csv("governor_text_detection.csv", index=False)

#attorney general: DONE
#ag_added.to_csv("ag_text_detection.csv", index=False)

#mayor: DONE
#mayor_added.to_csv("mayor_text_detection.csv", index=False)

#US Senate: DONE
#us_senate_added.to_csv("us_senate_detection.csv",index=False)

#US House

#State Senate

#State House

# %% [markdown]
# # Testing different sample lengths #
#
# We originally sampled 40% of the visible text to run Pangram on it. Now, I will sample 60% and 80% of the original text and see if it makes a significant difference in the amount of text identified as AI.

# %%
testing_totals = pd.concat([gov_added, ag_added, mayor_added, us_senate_added], ignore_index=True)
testing_totals
# Out:
#      content_id  candidate_id  candidate_name  \
# 0             1          6179    Andy Beshear
# 1             2          6180  Daniel Cameron
# 2             3          6180  Daniel Cameron
# 3             4          6180  Daniel Cameron
# 4             5          6180  Daniel Cameron
# ..          ...           ...             ...
# 545        2828          6155   Tammy Baldwin
# 546        2829          6158   Glenn Elliott
# 547        2830          6157     Jim Justice
# 548        2831          6157     Jim Justice
# 549        2832          6159   John Barrasso
#
#                                             page_url page_type      link_type  \
# 0                           https://andybeshear.com/      home  campaign_site
# 1                    https://cameronforkentucky.com/      home  campaign_site
# 2      https://cameronforkentucky.com/policies/terms    policy  campaign_site
# 3    https://cameronforkentucky.com/policies/privacy    policy  campaign_site
# 4             https://cameronforkentucky.com/issues/    policy  campaign_site
# ..                                               ...       ...            ...
# 545              https://www.tammybaldwin.com/about/     about  campaign_site
# 546                     https://www.elliottforwv.com      home  campaign_site
# 547                          http://jimjusticewv.com      home  campaign_site
# 548                 https://jimjusticewv.com/issues/    policy  campaign_site
# 549                  https://barrassoforwyoming.com/      home  campaign_site
#
#                                       unprocessed_text  \
# 0    Andy Beshear Menu Meet Andy Meet Jacqueline An...
# 1    Menu News Facebook Twitter Instagram Donate › ...
# 2    Menu News Facebook Twitter Instagram Donate › ...
# 3    Menu News Facebook Twitter Instagram Donate › ...
# 4    Menu News Facebook Twitter Instagram Donate › ...
# ..                                                 ...
# 545  About Tammy News Issues Get Involved Store Con...
# 546  Elliott Wave Forecast Login Start 14-Day Trial...
# 547  Skip to content Endorsed by Trump Meet Jim Acc...
# 548  Skip to content Endorsed by Trump Meet Jim Acc...
# 549  Skip to content Your Senator Get Involved Buy ...
#
#                                           cleaned_text  \
# 0    Andy Beshear Menu Meet Andy Meet Jacqueline An...
# 1    Menu News Facebook Twitter Instagram Donate  S...
# 2    Menu News Facebook Twitter Instagram Donate  S...
# 3    Menu News Facebook Twitter Instagram Donate  S...
# 4    Menu News Facebook Twitter Instagram Donate  S...
# ..                                                 ...
# 545  About Tammy News Issues Get Involved Store Con...
# 546  Elliott Wave Forecast Login Start 14-Day Trial...
# 547  Skip to content Endorsed by Trump Meet Jim Acc...
# 548  Skip to content Endorsed by Trump Meet Jim Acc...
# 549  Skip to content Your Senator Get Involved Buy ...
#
#                                           sampled_text  race_type  year  \
# 0    Andy Beshear Menu Meet Andy Meet Jacqueline An...   Governor  2023
# 1    I'm In! QUICK DONATE $25 $50 $100 ENTER AMOUNT...   Governor  2023
# 2    Data Privacy We will not share or sell your pe...   Governor  2023
# 3    This Privacy Policy explains how we collect, u...   Governor  2023
# 4    He will always oppose the radical green agenda...   Governor  2023
# ..                                                 ...        ...   ...
# 545  James Allen Veteran Vision Equity Act, passed ...  US Senate  2024
# 546  Retail Traders & Investors Join us never trade...  US Senate  2024
# 547  Message frequency may vary. Reply stop to stop...  US Senate  2024
# 548  Reply stop to stop and help for help. Mobile o...  US Senate  2024
# 549  Message and data rates may apply. Message freq...  US Senate  2024
#
#      AI_label  assistance_score  confidence  fraction_ai  \
# 0         NaN               NaN         NaN          NaN
# 1         NaN               NaN         NaN          NaN
# 2         NaN               NaN         NaN          NaN
# 3         NaN               NaN         NaN          NaN
# 4         NaN               NaN         NaN          NaN
# ..        ...               ...         ...          ...
# 545       NaN               NaN         NaN          NaN
# 546       NaN               NaN         NaN          NaN
# 547       NaN               NaN         NaN          NaN
# 548       NaN               NaN         NaN          NaN
# 549       NaN               NaN         NaN          NaN
#
#      fraction_ai_assisted  fraction_human  num_ai_segments
# 0                     NaN             NaN              NaN
# 1                     NaN             NaN              NaN
# 2                     NaN             NaN              NaN
# 3                     NaN             NaN              NaN
# 4                     NaN             NaN              NaN
# ..                    ...             ...              ...
# 545                   NaN             NaN              NaN
# 546                   NaN             NaN              NaN
# 547                   NaN             NaN              NaN
# 548                   NaN             NaN              NaN
# 549                   NaN             NaN              NaN
#
# [550 rows x 18 columns]

# %%
#use the same sampling method but fraction is 0.6
def _sample_text(text: str, fraction: float = 0.6, max_attempts: int = 5) -> str:
    """Return a contiguous ~40% sentence chunk starting at a random position.

    Retries up to max_attempts times to avoid chunks containing ``"ERROR"``.

    Args:
        text: Input text to sample from.
        fraction: Fraction of sentences to include.
        max_attempts: Maximum retry attempts to avoid ERROR-containing chunks.

    Returns:
        Sampled text string.
    """
    if not isinstance(text, str) or text.startswith("ERROR:") or text == "":
        return text
    sentences = [s.strip() for s in re.split(r"(?<=[.!?])\s+", text) if s.strip()]
    if not sentences:
        return text
    k = max(1, int(len(sentences) * fraction))
    max_start = max(0, len(sentences) - k)
    sample = ""
    for _ in range(max_attempts):
        start = random.randint(0, max_start)
        sample = " ".join(sentences[start : start + k])
        if "ERROR" not in sample:
            return sample
    return sample

# %%
combined_40['sampled_text'] = combined_40['column_name'].apply(_sample_text)
